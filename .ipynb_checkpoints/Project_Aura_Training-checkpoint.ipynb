# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
import joblib

plt.style.use('ggplot')

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('ai-python/FpsTest/fps_dataset.csv')

# %%
df.head()
# Out:
#                CPU  CPU Cores  CPU Threads  CPU TDP (W)         GPU  \
# 0  Intel i7-12700F         12           20           65    RTX 2070
# 1  Intel i5-12600K         10           16          125     RX 6800
# 2    Ryzen 9 5900X         12           24          105    RTX 3080
# 3  Intel i7-13700K         16           24          125    RTX 3070
# 4  Intel i5-12400F          6           12           65  RX 6900 XT
#
#   GPU Series  GPU VRAM (GB)  GPU Bandwidth (GB/s)  GPU TDP (W)  \
# 0   RTX 2000              8                   448          300
# 1    RX 6000             16                   512          150
# 2   RTX 3000             10                   760          200
# 3   RTX 3000              8                   448          200
# 4    RX 6000             16                   512          200
#
#    Total System TDP (W)  Bottleneck Score  RAM (GB) Resolution  \
# 0                   365              3.50         8  3840x2160
# 1                   275              5.00         8  1920x1080
# 2                   305              3.96         8  2560x1440
# 3                   325              3.33         8  2560x1440
# 4                   265              7.50        16  3840x2160
#
#   Graphics Settings  Min FPS  Avg FPS  Max FPS
# 0              High       28       35       43
# 1               Low       72       93      102
# 2              High       51       71       84
# 3               Low       60       80       93
# 4               Low       48       65       79

# %% [markdown]
# # Data Preprocessing

# %%
print(f"Original shape: {df.shape}")
# Out:
# Original shape: (1000, 17)

# %% [markdown]
# Separate target FPS from hardware features.....

# %%
y = df['Avg FPS']
X_raw  = df.drop(columns=['Avg FPS'])

# %% [markdown]
# Converting text to Numbers.....

# %%
X = pd.get_dummies(X_raw)
print(f"Encoded shape:{X.shape}")
# Out:
# Encoded shape:(1000, 75)

# %% [markdown]
# # Train and Test

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20, random_state=42)
print(f"Training on {len(X_train)} setups, Testing on {len(X_test)} setups.")
# Out:
# Training on 800 setups, Testing on 200 setups.

# %% [markdown]
# # Train Random Forest Model

# %% [markdown]
# Initial model with 100 trees....

# %%
model = RandomForestRegressor(n_estimators=100, random_state=42)

# %% [markdown]
# Train the model....

# %%
model.fit(X_train, y_train)
print("Model train Complete!")
# Out:
# Model train Complete!
